# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('FIFA WORLD CUP.xlsx')

# %%
df['WORTH (€)'] = df['WORTH (€)'].str.replace('M', '')
df['WORTH (€)'] = df['WORTH (€)'].astype(float)
df.head()
# Out:
#   GROUP COUNTRY  NO.             NAME POSITION  HEIGHT  WORTH (€)       BIRTH  \
# 0     A   QATAR    1    Saad Al Sheeb       GK     185      0.200  1990.02.19
# 1     A   QATAR   21    Yousef Hassan       GK     186      0.150  1996.05.24
# 2     A   QATAR   22  Meshaal Barsham       GK     178      0.450  1998.02.14
# 3     A   QATAR    2            Ró-Ró       DF     182      0.325  1990.08.06
# 4     A   QATAR    4    Mohammed Waad       DF     183      0.400  1999.09.18
#
#    AGE        CLUB  ... Unnamed: 21  Unnamed: 22  Unnamed: 23  Unnamed: 24  \
# 0   32     Al-Sadd  ...         NaN          NaN          NaN          NaN
# 1   26  Al-Gharafa  ...         NaN          NaN          NaN          NaN
# 2   24     Al-Sadd  ...         NaN          NaN          NaN          NaN
# 3   32     Al-Sadd  ...         NaN          NaN          NaN          NaN
# 4   23     Al-Sadd  ...         NaN          NaN          NaN          NaN
#
# ...

# %%
df.groupby('GROUP')['HEIGHT'].describe()
# Out:
#        count        mean       std    min     25%    50%    75%    max
# GROUP
# A      104.0  181.894231  7.471523  167.0  176.75  182.0  187.0  203.0
# B      103.0  182.669903  6.886173  168.0  178.00  183.0  187.0  198.0
# C      104.0  180.480769  7.060049  167.0  174.00  180.0  186.0  196.0
# D      103.0  184.009709  5.871993  165.0  180.00  184.0  187.5  198.0
# E      104.0  182.105769  6.790797  166.0  177.00  182.0  188.0  197.0
# F      104.0  184.000000  7.278109  160.0  178.00  185.0  188.0  200.0
# G      104.0  183.509615  6.714707  165.0  180.00  184.0  188.0  202.0
# H      104.0  181.413462  6.553159  163.0  177.00  182.0  187.0  196.0

# %%
df.groupby('GROUP')['AGE'].describe()
# Out:
#        count       mean       std   min    25%   50%    75%   max
# GROUP
# A      104.0  26.413462  4.184137  19.0  23.00  26.0  29.25  39.0
# B      103.0  26.747573  3.867204  19.0  24.00  27.0  29.00  35.0
# C      104.0  27.653846  4.325964  20.0  24.00  27.0  31.00  40.0
# D      103.0  27.106796  4.110991  18.0  24.00  27.0  30.00  38.0
# E      104.0  26.769231  4.857645  18.0  23.00  27.0  30.00  39.0
# F      104.0  27.076923  4.350410  18.0  24.00  27.0  30.00  39.0
# G      104.0  27.019231  3.869173  19.0  24.75  27.0  30.00  39.0
# H      104.0  26.788462  4.512492  18.0  23.00  26.0  30.00  39.0

# %%
df.groupby('COUNTRY')['WORTH (€)'].describe()
# Out:
#                count       mean        std    min      25%      50%       75%  \
# COUNTRY
# Argentina       26.0  24.700000  18.219660   3.00  10.5000  21.5000  32.00000
# Australia       26.0   1.434615   1.249381   0.15   0.7000   0.9000   1.80000
# Belgium         26.0  21.661538  19.595430   1.80   7.6250  16.5000  30.00000
# Brazil          26.0  43.923077  30.390687   1.00  15.5000  50.0000  60.00000
# Cameroon        26.0   5.961538   8.723581   0.30   1.3500   3.7500   5.37500
# Canada          26.0   7.223077  15.462401   0.10   0.9750   2.4000   5.50000
# Costa Rica      26.0   0.724038   1.065399   0.15   0.2500   0.2750   0.61875
# Croatia         26.0  14.500000  13.407461   2.00   6.1250   9.0000  20.00000
# Denmark         26.0  12.073077   8.827845   2.00   4.6250  11.0000  14.75000
# Ecuador         26.0   5.617308   8.562207   0.30   1.5750   3.0000   4.00000
# England         26.0  48.461538  29.561097  13.00  28.0000  38.5000  70.00000
# ...

# %%
plt.plot(df.groupby('GROUP')['AGE'].mean())
plt.grid(color='g', linestyle='-')

# %%
#Group A data
dfQATAR = df[df['COUNTRY'] == 'QATAR']
dfEcuador = df[df['COUNTRY'] == 'Ecuador']
dfSenegal = df[df['COUNTRY'] == 'Senegal']
dfNetherlands = df[df['COUNTRY'] == 'Netherlands']
QatarWorth = dfQATAR['WORTH (€)']
EcuadorWorth = dfEcuador['WORTH (€)']
SenegalWorth = dfSenegal['WORTH (€)']
NetherlandsWorth = dfNetherlands['WORTH (€)']

# %%
plt.boxplot(QatarWorth)
plt.show()

# %%
GroupA = [QatarWorth,EcuadorWorth,SenegalWorth,NetherlandsWorth]
plt.boxplot(GroupA,labels=('Qatar','Ecuador','Senegal','Netherlands'))
plt.show()

# %%
plt.plot(QatarWorth)

# %%
dfEngland = df[df['COUNTRY'] == 'England']
dfIran = df[df['COUNTRY'] == 'Iran']
dfUnitedStates = df[df['COUNTRY'] == 'United States']
dfWales = df[df['COUNTRY'] == 'Wales']
EnglandWorth = dfEngland['WORTH (€)']
IranWorth = dfIran['WORTH (€)']
UnitedStatesWorth = dfUnitedStates['WORTH (€)']
WalesWorth = dfWales['WORTH (€)']

# %%
GroupB = [EnglandWorth,IranWorth,UnitedStatesWorth,WalesWorth]
plt.boxplot(GroupB,labels=('England','Iran','United States','Wales'))
plt.show()

# %%
dfArgentina = df[df['COUNTRY'] == 'Argentina']
dfMexico = df[df['COUNTRY'] == 'Mexico']
dfPoland = df[df['COUNTRY'] == 'Poland']
dfSaudiArabia = df[df['COUNTRY'] == 'Saudi Arabia']
ArgentinaWorth = dfArgentina['WORTH (€)']
MexicoWorth = dfMexico['WORTH (€)']
PolandWorth = dfPoland['WORTH (€)']
SaudiArabiaWorth = dfSaudiArabia['WORTH (€)']

# %%
GroupC = [ArgentinaWorth,MexicoWorth,PolandWorth,SaudiArabiaWorth]
plt.boxplot(GroupC,labels=('Argentina','Mexico','Poland','Saudi Arabia'))
plt.show()

# %%
#D
dfAustralia = df[df['COUNTRY'] == 'Australia']
dfDenmark = df[df['COUNTRY'] == 'Denmark']
dfFrance = df[df['COUNTRY'] == 'France']
dfTunisia = df[df['COUNTRY'] == 'Tunisia']
AustraliaWorth = dfAustralia['WORTH (€)']
DenmarkWorth = dfDenmark['WORTH (€)']
FranceWorth = dfFrance['WORTH (€)']
TunisiaWorth = dfTunisia['WORTH (€)']

# %%
GroupD = [AustraliaWorth,DenmarkWorth,FranceWorth,TunisiaWorth]
plt.boxplot(GroupD,labels=('Australia','Denmark','France','Tunisia'))
plt.show()

# %%
dfCostaRica = df[df['COUNTRY'] == 'Costa Rica']
dfGermany = df[df['COUNTRY'] == 'Germany']
dfJapan = df[df['COUNTRY'] == 'Japan']
dfSpain = df[df['COUNTRY'] == 'Spain']
CostaRicaWorth = dfCostaRica['WORTH (€)']
GermanyWorth = dfGermany['WORTH (€)']
JapanWorth = dfJapan['WORTH (€)']
SpainWorth = dfSpain['WORTH (€)']

# %%
GroupE = [CostaRicaWorth,GermanyWorth,JapanWorth,SpainWorth]
plt.boxplot(GroupE,labels=('Costa Rica','Germany','Japan','Spain'))
plt.show()

# %%
dfBelgium = df[df['COUNTRY'] == 'Belgium']
dfCanada = df[df['COUNTRY'] == 'Canada']
dfCroatia = df[df['COUNTRY'] == 'Croatia']
dfMorocco = df[df['COUNTRY'] == 'Morocco']
BelgiumWorth = dfBelgium['WORTH (€)']
CanadaWorth = dfCanada['WORTH (€)']
CroatiaWorth = dfCroatia['WORTH (€)']
MoroccoWorth = dfMorocco['WORTH (€)']

# %%
GroupF = [BelgiumWorth,CanadaWorth,CroatiaWorth,MoroccoWorth]
plt.boxplot(GroupF,labels=('Belgium','Canada','Croatia','Morocco'))
plt.show()

# %%
dfBrazil = df[df['COUNTRY'] == 'Brazil']
dfCameroon = df[df['COUNTRY'] == 'Cameroon']
dfSerbia = df[df['COUNTRY'] == 'Serbia']
dfSwitzerland = df[df['COUNTRY'] == 'Switzerland']
BrazilWorth = dfBrazil['WORTH (€)']
CameroonWorth = dfCameroon['WORTH (€)']
SerbiaWorth = dfSerbia['WORTH (€)']
SwitzerlandWorth = dfSwitzerland['WORTH (€)']

# %%
GroupG= [BrazilWorth,CameroonWorth,SerbiaWorth,SwitzerlandWorth]
plt.boxplot(GroupG,labels=('Brazil','Cameroon','Serbia','Switzerland'))
plt.show()

# %%
dfGhana = df[df['COUNTRY'] == 'Ghana']
dfPortugal = df[df['COUNTRY'] == 'Portugal']
dfSouthKorea = df[df['COUNTRY'] == 'South Korea']
dfUruguay = df[df['COUNTRY'] == 'Uruguay']
GhanaWorth = dfGhana['WORTH (€)']
PortugalWorth = dfPortugal['WORTH (€)']
SouthKoreaWorth = dfSouthKorea['WORTH (€)']
UruguayWorth = dfUruguay['WORTH (€)']

# %%
GroupH = [GhanaWorth,PortugalWorth,SouthKoreaWorth,UruguayWorth]
plt.boxplot(GroupH,labels=('Ghana','Portugal','South Korea','Uruguay'))
plt.show()

# %%
ABCD = [QatarWorth,EcuadorWorth,SenegalWorth,NetherlandsWorth,EnglandWorth,IranWorth,UnitedStatesWorth,WalesWorth,ArgentinaWorth,MexicoWorth,PolandWorth,SaudiArabiaWorth,AustraliaWorth,DenmarkWorth,FranceWorth,TunisiaWorth]
fig = plt.figure()
fig.set_figheight(5)
fig.set_figwidth(15)
plt.boxplot(ABCD)
plt.show()

# %%
df.groupby('POSITION')['WORTH (€)'].describe()
# Out:
#           count       mean        std   min  25%   50%   75%    max
# POSITION
# DF        271.0  12.652122  16.714154  0.10  1.5   5.0  18.0   75.0
# FW        189.0  20.612831  25.938639  0.25  3.4  10.0  30.0  160.0
# GK         99.0   7.407828  11.561317  0.05  0.7   2.5   8.0   60.0
# MF        271.0  15.595387  21.870982  0.10  1.8   6.0  18.5  110.0

# %%
dfGK = df[df['POSITION'] == 'GK']
GKWorth = dfGK['WORTH (€)']
plt.plot(GKWorth)

# %%
plt.boxplot(GKWorth)
plt.show()

# %%
dfDF = df[df['POSITION'] == 'DF']
DFWorth = dfDF['WORTH (€)']
plt.plot(DFWorth)

# %%
plt.boxplot(DFWorth)
plt.show()

# %%
dfMF = df[df['POSITION'] == 'MF']
MFWorth = dfMF['WORTH (€)']
plt.plot(MFWorth)

# %%
plt.boxplot(MFWorth)
plt.show()

# %%
dfFW = df[df['POSITION'] == 'FW']
FWWorth = dfFW['WORTH (€)']
plt.plot(FWWorth)

# %%
plt.boxplot(FWWorth)
plt.show()

# %%
pos = [GKWorth,DFWorth,MFWorth,FWWorth]
plt.boxplot(pos,labels=('GK','DF','MF','FW'))
plt.show()

# %%
from matplotlib.pyplot import figure


QatarSum = dfQATAR['WORTH (€)'].sum()
EcuadorSum = dfEcuador['WORTH (€)'].sum()
SenegalSum = dfSenegal['WORTH (€)'].sum()
NetherlandsSum = dfNetherlands['WORTH (€)'].sum()
EnglandSum = dfEngland['WORTH (€)'].sum()
IranSum = dfIran['WORTH (€)'].sum()
UnitedStatesSum = dfUnitedStates['WORTH (€)'].sum()
WalesSum = dfWales['WORTH (€)'].sum()

import matplotlib.pyplot as plt



Sums = [QatarSum, EcuadorSum, SenegalSum, NetherlandsSum,EnglandSum,IranSum,UnitedStatesSum,WalesSum]
countries = ['Qatar','Ecuador','Senegal','Netherlands','England','Iran','United States','Wales']



plt.bar(countries, Sums)




from matplotlib.pyplot import figure

figure(figsize=(20, 10), dpi=80)

plt.show()

# %%
from matplotlib.pyplot import figure

figure(figsize=(20, 10), dpi=80)
plt.plot(GKWorth)
plt.plot(DFWorth)
plt.plot(MFWorth)
plt.plot(FWWorth)
plt.legend(['GK','DF','MF','FW'],loc='best')

# %%
print('Qatar Worth:' ,dfQATAR['WORTH (€)'].sum())
print('Ecuador Worth:' ,dfEcuador['WORTH (€)'].sum())
print('Senegal Worth:' ,dfSenegal['WORTH (€)'].sum())
print('Netherlands Worth:' ,dfNetherlands['WORTH (€)'].sum())
# Out:
# Qatar Worth: 14.9
# Ecuador Worth: 146.05
# Senegal Worth: 220.35
# Netherlands Worth: 587.25

# %%
#Qatar Position Data
dfQatarGK = dfQATAR[dfQATAR['POSITION'] == 'GK']
dfQatarDF = dfQATAR[dfQATAR['POSITION'] == 'DF']
dfQatarMF = dfQATAR[dfQATAR['POSITION'] == 'MF']
dfQatarFW = dfQATAR[dfQATAR['POSITION'] == 'FW']
#Ecuador Position Data
dfEcuadorGK = dfEcuador[dfEcuador['POSITION'] == 'GK']
dfEcuadorDF = dfEcuador[dfEcuador['POSITION'] == 'DF']
dfEcuadorMF = dfEcuador[dfEcuador['POSITION'] == 'MF']
dfEcuadorFW = dfEcuador[dfEcuador['POSITION'] == 'FW']
#Senegal Position Data
dfSenegalGK = dfSenegal[dfSenegal['POSITION'] == 'GK']
dfSenegalDF = dfSenegal[dfSenegal['POSITION'] == 'DF']
dfSenegalMF = dfSenegal[dfSenegal['POSITION'] == 'MF']
dfSenegalFW = dfSenegal[dfSenegal['POSITION'] == 'FW']
#Netherlands Position Data
dfNetherlandsGK = dfNetherlands[dfNetherlands['POSITION'] == 'GK']
dfNetherlandsDF = dfNetherlands[dfNetherlands['POSITION'] == 'DF']
dfNetherlandsMF = dfNetherlands[dfNetherlands['POSITION'] == 'MF']
dfNetherlandsFW = dfNetherlands[dfNetherlands['POSITION'] == 'FW']


plt.subplot(2,2,1)
plt.plot(dfQatarGK['WORTH (€)'])
plt.plot(dfQatarDF['WORTH (€)'])
plt.plot(dfQatarMF['WORTH (€)'])
plt.plot(dfQatarFW['WORTH (€)'])
plt.title('Qatar Position Worth')
plt.legend(['GK','DF','MF','FW'],loc='upper left')


plt.subplot(2,2,2)
plt.plot(dfEcuadorGK['WORTH (€)'])
plt.plot(dfEcuadorDF['WORTH (€)'])
plt.plot(dfEcuadorMF['WORTH (€)'])
plt.plot(dfEcuadorFW['WORTH (€)'])
plt.title('Ecuador Position Worth')

plt.subplot(2,2,3)
plt.plot(dfSenegalGK['WORTH (€)'])
plt.plot(dfSenegalDF['WORTH (€)'])
plt.plot(dfSenegalMF['WORTH (€)'])
plt.plot(dfSenegalFW['WORTH (€)'])
plt.title('Senegal Position Worth')

plt.subplot(2,2,4)
plt.plot(dfNetherlandsGK['WORTH (€)'])
plt.plot(dfNetherlandsDF['WORTH (€)'])
plt.plot(dfNetherlandsMF['WORTH (€)'])
plt.plot(dfNetherlandsFW['WORTH (€)'])
plt.title('Netherlands Position Worth')

plt.tight_layout()

plt.suptitle("Group A Position and Worth", fontsize=18,color='blue',y=1.05)
# Out:
# Text(0.5, 1.05, 'Group A Position and Worth')

# %%
plt.plot(dfQatarGK['WORTH (€)'])
plt.plot(dfQatarDF['WORTH (€)'])
plt.plot(dfQatarMF['WORTH (€)'])
plt.plot(dfQatarFW['WORTH (€)'])
plt.plot(dfNetherlandsGK['WORTH (€)'])
plt.plot(dfNetherlandsDF['WORTH (€)'])
plt.plot(dfNetherlandsMF['WORTH (€)'])
plt.plot(dfNetherlandsFW['WORTH (€)'])
plt.legend(['Qatar GK','Qatar DF','Qatar MF','Qatar FW','Netherlands GK','Netherlands DF','Netherlands MF','Netherlands FW'])
plt.title('The two countries with the largest gap: Qatar and Netherlands',fontsize = 18,color='orange')
# Out:
# Text(0.5, 1.0, 'The two countries with the largest gap: Qatar and Netherlands')

# %%
#England Position Data
dfEnglandGK = dfEngland[dfEngland['POSITION'] == 'GK']
dfEnglandDF = dfEngland[dfEngland['POSITION'] == 'DF']
dfEnglandMF = dfEngland[dfEngland['POSITION'] == 'MF']
dfEnglandFW = dfEngland[dfEngland['POSITION'] == 'FW']
#Iran Position Data
dfIranGK = dfIran[dfIran['POSITION'] == 'GK']
dfIranDF = dfIran[dfIran['POSITION'] == 'DF']
dfIranMF = dfIran[dfIran['POSITION'] == 'MF']
dfIranFW = dfIran[dfIran['POSITION'] == 'FW']
#United States Position Data
dfUnitedStatesGK = dfUnitedStates[dfUnitedStates['POSITION'] == 'GK']
dfUnitedStatesDF = dfUnitedStates[dfUnitedStates['POSITION'] == 'DF']
dfUnitedStatesMF = dfUnitedStates[dfUnitedStates['POSITION'] == 'MF']
dfUnitedStatesFW = dfUnitedStates[dfUnitedStates['POSITION'] == 'FW']
#Wales Position Data
dfWalesGK = dfWales[dfWales['POSITION'] == 'GK']
dfWalesDF = dfWales[dfWales['POSITION'] == 'DF']
dfWalesMF = dfWales[dfWales['POSITION'] == 'MF']
dfWalesFW = dfWales[dfWales['POSITION'] == 'FW']


plt.subplot(2,2,1)
plt.plot(dfEnglandGK['WORTH (€)'])
plt.plot(dfEnglandDF['WORTH (€)'])
plt.plot(dfEnglandMF['WORTH (€)'])
plt.plot(dfEnglandFW['WORTH (€)'])
plt.title('England Position Worth')
plt.legend(['GK','DF','MF','FW'],loc='upper left')


plt.subplot(2,2,2)
plt.plot(dfIranGK['WORTH (€)'])
plt.plot(dfIranDF['WORTH (€)'])
plt.plot(dfIranMF['WORTH (€)'])
plt.plot(dfIranFW['WORTH (€)'])
plt.title('Iran Position Worth')

plt.subplot(2,2,3)
plt.plot(dfUnitedStatesGK['WORTH (€)'])
plt.plot(dfUnitedStatesDF['WORTH (€)'])
plt.plot(dfUnitedStatesMF['WORTH (€)'])
plt.plot(dfUnitedStatesFW['WORTH (€)'])
plt.title('United States Position Worth')

plt.subplot(2,2,4)
plt.plot(dfWalesGK['WORTH (€)'])
plt.plot(dfWalesDF['WORTH (€)'])
plt.plot(dfWalesMF['WORTH (€)'])
plt.plot(dfWalesFW['WORTH (€)'])
plt.title('Wales Position Worth')

plt.tight_layout()

plt.suptitle("Group B Position and Worth", fontsize=18,color='blue',y=1.05)
# Out:
# Text(0.5, 1.05, 'Group B Position and Worth')

# %%
plt.plot(dfEnglandGK['WORTH (€)'])
plt.plot(dfEnglandDF['WORTH (€)'])
plt.plot(dfEnglandMF['WORTH (€)'])
plt.plot(dfEnglandFW['WORTH (€)'])
plt.plot(dfIranGK['WORTH (€)'])
plt.plot(dfIranDF['WORTH (€)'])
plt.plot(dfIranMF['WORTH (€)'])

plt.plot(dfIranFW['WORTH (€)'])
plt.legend(['England GK','England DF','England MF','England FW','Iran GK','Iran DF','Iran MF','Iran FW'])
plt.title('The two countries with the largest gap: England and Iran', fontsize = 18, color = 'orange')
# Out:
# Text(0.5, 1.0, 'The two countries with the largest gap: England and Iran')

# %%
#Argentina Position Data
dfArgentinaGK = dfArgentina[dfArgentina['POSITION'] == 'GK']
dfArgentinaDF = dfArgentina[dfArgentina['POSITION'] == 'DF']
dfArgentinaMF = dfArgentina[dfArgentina['POSITION'] == 'MF']
dfArgentinaFW = dfArgentina[dfArgentina['POSITION'] == 'FW']
#Mexico Position Data
dfMexicoGK = dfMexico[dfMexico['POSITION'] == 'GK']
dfMexicoDF = dfMexico[dfMexico['POSITION'] == 'DF']
dfMexicoMF = dfMexico[dfMexico['POSITION'] == 'MF']
dfMexicoFW = dfMexico[dfMexico['POSITION'] == 'FW']
#Poland Position Data
dfPolandGK = dfPoland[dfPoland['POSITION'] == 'GK']
dfPolandDF = dfPoland[dfPoland['POSITION'] == 'DF']
dfPolandMF = dfPoland[dfPoland['POSITION'] == 'MF']
dfPolandFW = dfPoland[dfPoland['POSITION'] == 'FW']
#Saudi Arabia Position Data
dfSaudiArabiaGK = dfSaudiArabia[dfSaudiArabia ['POSITION'] == 'GK']
dfSaudiArabiaDF = dfSaudiArabia[dfSaudiArabia ['POSITION'] == 'DF']
dfSaudiArabiaMF = dfSaudiArabia[dfSaudiArabia ['POSITION'] == 'MF']
dfSaudiArabiaFW = dfSaudiArabia[dfSaudiArabia ['POSITION'] == 'FW']


plt.subplot(2,2,1)
plt.plot(dfArgentinaGK['WORTH (€)'])
plt.plot(dfArgentinaDF['WORTH (€)'])
plt.plot(dfArgentinaMF['WORTH (€)'])
plt.plot(dfArgentinaFW['WORTH (€)'])
plt.title('Argentina Position Worth')
plt.legend(['GK','DF','MF','FW'],loc='upper left')


plt.subplot(2,2,2)
plt.plot(dfMexicoGK['WORTH (€)'])
plt.plot(dfMexicoDF['WORTH (€)'])
plt.plot(dfMexicoMF['WORTH (€)'])
plt.plot(dfMexicoFW['WORTH (€)'])
plt.title('Mexico Position Worth')

plt.subplot(2,2,3)
plt.plot(dfPolandGK['WORTH (€)'])
plt.plot(dfPolandDF['WORTH (€)'])
plt.plot(dfPolandMF['WORTH (€)'])
plt.plot(dfPolandFW['WORTH (€)'])
plt.title('Poland Position Worth')

plt.subplot(2,2,4)
plt.plot(dfSaudiArabiaGK['WORTH (€)'])
plt.plot(dfSaudiArabiaDF['WORTH (€)'])
plt.plot(dfSaudiArabiaMF['WORTH (€)'])
plt.plot(dfSaudiArabiaFW['WORTH (€)'])
plt.title('Saudi Arabia Position Worth')

plt.tight_layout()

plt.suptitle("Group C Position and Worth", fontsize=18,color='blue',y=1.05)
# Out:
# Text(0.5, 1.05, 'Group C Position and Worth')

# %%
plt.plot(dfSaudiArabiaGK['WORTH (€)'])
plt.plot(dfSaudiArabiaDF['WORTH (€)'])
plt.plot(dfSaudiArabiaMF['WORTH (€)'])
plt.plot(dfSaudiArabiaFW['WORTH (€)'])
plt.plot(dfArgentinaGK['WORTH (€)'])
plt.plot(dfArgentinaDF['WORTH (€)'])
plt.plot(dfArgentinaMF['WORTH (€)'])
plt.plot(dfArgentinaFW['WORTH (€)'])
plt.legend(['Saudi Arabia GK','Saudi Arabia DF','Saudi Arabia MF','Saudi Arabia FW','Argentina GK','Argentina DF','Argentina MF','Argentina FW'])
plt.title('The two countries with the largest gap: Saudia Arabia and Argentina', fontsize = 18, color = 'orange')
# Out:
# Text(0.5, 1.0, 'The two countries with the largest gap: Saudia Arabia and Argentina')

# %%
#Australia Position Data
dfAustraliaGK = dfAustralia[dfAustralia['POSITION'] == 'GK']
dfAustraliaDF = dfAustralia[dfAustralia['POSITION'] == 'DF']
dfAustraliaMF = dfAustralia[dfAustralia['POSITION'] == 'MF']
dfAustraliaFW = dfAustralia[dfAustralia['POSITION'] == 'FW']
#Denmark Position Data
dfDenmarkGK = dfDenmark[dfDenmark['POSITION'] == 'GK']
dfDenmarkDF = dfDenmark[dfDenmark['POSITION'] == 'DF']
dfDenmarkMF = dfDenmark[dfDenmark['POSITION'] == 'MF']
dfDenmarkFW = dfDenmark[dfDenmark['POSITION'] == 'FW']
#France Position Data
dfFranceGK = dfFrance[dfFrance['POSITION'] == 'GK']
dfFranceDF = dfFrance[dfFrance['POSITION'] == 'DF']
dfFranceMF = dfFrance[dfFrance['POSITION'] == 'MF']
dfFranceFW = dfFrance[dfFrance['POSITION'] == 'FW']
#Tunisia Position Data
dfTunisiaGK = dfTunisia[dfTunisia['POSITION'] == 'GK']
dfTunisiaDF = dfTunisia[dfTunisia['POSITION'] == 'DF']
dfTunisiaMF = dfTunisia[dfTunisia['POSITION'] == 'MF']
dfTunisiaFW = dfTunisia[dfTunisia['POSITION'] == 'FW']

plt.subplot(2,2,1)
plt.plot(dfAustraliaGK['WORTH (€)'])
plt.plot(dfAustraliaDF['WORTH (€)'])
plt.plot(dfAustraliaMF['WORTH (€)'])
plt.plot(dfAustraliaFW['WORTH (€)'])
plt.title('Australia Position Worth')
plt.legend(['GK','DF','MF','FW'],loc='upper right')


plt.subplot(2,2,2)
plt.plot(dfDenmarkGK['WORTH (€)'])
plt.plot(dfDenmarkDF['WORTH (€)'])
plt.plot(dfDenmarkMF['WORTH (€)'])
plt.plot(dfDenmarkFW['WORTH (€)'])
plt.title('Denmark Position Worth')

plt.subplot(2,2,3)
plt.plot(dfFranceGK['WORTH (€)'])
plt.plot(dfFranceDF['WORTH (€)'])
plt.plot(dfFranceMF['WORTH (€)'])
plt.plot(dfFranceFW['WORTH (€)'])
plt.title('France Position Worth')


plt.subplot(2,2,4)
plt.plot(dfTunisiaGK['WORTH (€)'])
plt.plot(dfTunisiaDF['WORTH (€)'])
plt.plot(dfTunisiaMF['WORTH (€)'])
plt.plot(dfTunisiaFW['WORTH (€)'])
plt.title('Tunisia Position Worth')

plt.tight_layout()

plt.suptitle("Group D Position and Worth", fontsize=18,color='blue',y=1.05)
# Out:
# Text(0.5, 1.05, 'Group D Position and Worth')

# %%
plt.plot(dfAustraliaGK['WORTH (€)'])
plt.plot(dfAustraliaDF['WORTH (€)'])
plt.plot(dfAustraliaMF['WORTH (€)'])
plt.plot(dfAustraliaFW['WORTH (€)'])
plt.plot(dfFranceGK['WORTH (€)'])
plt.plot(dfFranceDF['WORTH (€)'])
plt.plot(dfFranceMF['WORTH (€)'])
plt.plot(dfFranceFW['WORTH (€)'])
plt.legend(['Australia GK','Australia DF','Australia MF','Australia FW','France GK','France DF','France MF','France FW'])
plt.title('The two countries with the largest gap: Australia and France', fontsize = 18, color = 'orange')
# Out:
# Text(0.5, 1.0, 'The two countries with the largest gap: Australia and France')

# %%
#Costa Rica Position Data
dfCostaRicaGK = dfCostaRica[dfCostaRica['POSITION'] == 'GK']
dfCostaRicaDF = dfCostaRica[dfCostaRica['POSITION'] == 'DF']
dfCostaRicaMF = dfCostaRica[dfCostaRica['POSITION'] == 'MF']
dfCostaRicaFW = dfCostaRica[dfCostaRica['POSITION'] == 'FW']

#Germany Position Data
dfGermanyGK = dfGermany[dfGermany['POSITION'] == 'GK']
dfGermanyDF = dfGermany[dfGermany['POSITION'] == 'DF']
dfGermanyMF = dfGermany[dfGermany['POSITION'] == 'MF']
dfGermanyFW = dfGermany[dfGermany['POSITION'] == 'FW']

#Japan Position Data
dfJapanGK = dfJapan[dfJapan['POSITION'] == 'GK']
dfJapanDF = dfJapan[dfJapan['POSITION'] == 'DF']
dfJapanMF = dfJapan[dfJapan['POSITION'] == 'MF']
dfJapanFW = dfJapan[dfJapan['POSITION'] == 'FW']

#Spain Position Data
dfSpainGK = dfSpain[dfSpain['POSITION'] == 'GK']
dfSpainDF = dfSpain[dfSpain['POSITION'] == 'DF']
dfSpainMF = dfSpain[dfSpain['POSITION'] == 'MF']
dfSpainFW = dfSpain[dfSpain['POSITION'] == 'FW']

plt.subplot(2,2,1)
plt.plot(dfCostaRicaGK['WORTH (€)'])
plt.plot(dfCostaRicaDF['WORTH (€)'])
plt.plot(dfCostaRicaMF['WORTH (€)'])
plt.plot(dfCostaRicaFW['WORTH (€)'])
plt.title('Costa Rica Position Worth')
plt.legend(['GK','DF','MF','FW'])

plt.subplot(2,2,2)
plt.plot(dfGermanyGK['WORTH (€)'])
plt.plot(dfGermanyDF['WORTH (€)'])
plt.plot(dfGermanyMF['WORTH (€)'])
plt.plot(dfGermanyFW['WORTH (€)'])
plt.title('Germany Position Worth')

plt.subplot(2,2,3)
plt.plot(dfJapanGK['WORTH (€)'])
plt.plot(dfJapanDF['WORTH (€)'])
plt.plot(dfJapanMF['WORTH (€)'])
plt.plot(dfJapanFW['WORTH (€)'])
plt.title('Japan Position Worth')

plt.subplot(2,2,4)
plt.plot(dfSpainGK['WORTH (€)'])
plt.plot(dfSpainDF['WORTH (€)'])
plt.plot(dfSpainMF['WORTH (€)'])
plt.plot(dfSpainFW['WORTH (€)'])
plt.title('Spain Position Worth')

plt.tight_layout()

plt.suptitle("Group E Position and Worth", fontsize=18,color='blue',y=1.05)
# Out:
# Text(0.5, 1.05, 'Group E Position and Worth')

# %%
plt.plot(dfCostaRicaGK['WORTH (€)'])
plt.plot(dfCostaRicaDF['WORTH (€)'])
plt.plot(dfCostaRicaMF['WORTH (€)'])
plt.plot(dfCostaRicaFW['WORTH (€)'])
plt.plot(dfSpainGK['WORTH (€)'])
plt.plot(dfSpainDF['WORTH (€)'])
plt.plot(dfSpainMF['WORTH (€)'])
plt.plot(dfSpainFW['WORTH (€)'])
plt.legend(['Costa Rica GK','Costa Rica DF','Costa Rica MF','Costa Rica FW','Spain GK','Spain DF','Spain MF','Spain FW'])
plt.title('The two countries with the largest gap: Costa Rica and Spain', fontsize = 18, color = 'orange')
# Out:
# Text(0.5, 1.0, 'The two countries with the largest gap: Costa Rica and Spain')

# %%
#Belgium Position Data
dfBelgiumGK = dfBelgium[dfBelgium['POSITION'] == 'GK']
dfBelgiumDF = dfBelgium[dfBelgium['POSITION'] == 'DF']
dfBelgiumMF = dfBelgium[dfBelgium['POSITION'] == 'MF']
dfBelgiumFW = dfBelgium[dfBelgium['POSITION'] == 'FW']

#Canada Position Data
dfCanadaGK = dfCanada[dfCanada['POSITION'] == 'GK']
dfCanadaDF = dfCanada[dfCanada['POSITION'] == 'DF']
dfCanadaMF = dfCanada[dfCanada['POSITION'] == 'MF']
dfCanadaFW = dfCanada[dfCanada['POSITION'] == 'FW']

#Croatia Position Data
dfCroatiaGK = dfCroatia[dfCroatia['POSITION'] == 'GK']
dfCroatiaDF = dfCroatia[dfCroatia['POSITION'] == 'DF']
dfCroatiaMF = dfCroatia[dfCroatia['POSITION'] == 'MF']
dfCroatiaFW = dfCroatia[dfCroatia['POSITION'] == 'FW']

#Morocco Position Data
dfMoroccoGK = dfMorocco[dfMorocco['POSITION'] == 'GK']
dfMoroccoDF = dfMorocco[dfMorocco['POSITION'] == 'DF']
dfMoroccoMF = dfMorocco[dfMorocco['POSITION'] == 'MF']
dfMoroccoFW = dfMorocco[dfMorocco['POSITION'] == 'FW']

plt.subplot(2,2,1)
plt.plot(dfBelgiumGK['WORTH (€)'])
plt.plot(dfBelgiumDF['WORTH (€)'])
plt.plot(dfBelgiumMF['WORTH (€)'])
plt.plot(dfBelgiumFW['WORTH (€)'])
plt.title('Belgium Position Worth')

plt.subplot(2,2,2)
plt.plot(dfCanadaGK['WORTH (€)'])
plt.plot(dfCanadaDF['WORTH (€)'])
plt.plot(dfCanadaMF['WORTH (€)'])
plt.plot(dfCanadaFW['WORTH (€)'])
plt.title('Canada Position Worth')
plt.legend(['GK','DF','MF','FW'],loc='upper left')


plt.subplot(2,2,3)
plt.plot(dfCroatiaGK['WORTH (€)'])
plt.plot(dfCroatiaDF['WORTH (€)'])
plt.plot(dfCroatiaMF['WORTH (€)'])
plt.plot(dfCroatiaFW['WORTH (€)'])
plt.title('Croatia Position Worth')

plt.subplot(2,2,4)
plt.plot(dfMoroccoGK['WORTH (€)'])
plt.plot(dfMoroccoDF['WORTH (€)'])
plt.plot(dfMoroccoMF['WORTH (€)'])
plt.plot(dfMoroccoFW['WORTH (€)'])
plt.title('Morocco Position Worth')

plt.tight_layout()

plt.suptitle("Group F Position and Worth", fontsize=18,color='blue',y=1.05)
# Out:
# Text(0.5, 1.05, 'Group F Position and Worth')

# %%
dfBelgium(['WORTH (€)'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/tungyuchen/Desktop/FIFA/FIFA.ipynb Cell 51' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/tungyuchen/Desktop/FIFA/FIFA.ipynb#ch0000050?line=0'>1</a> dfBelgium(['WORTH (€)'])
#
# TypeError: 'DataFrame' object is not callable

# %%
#Brazil Position Data
dfBrazilGK = dfBrazil[dfBrazil['POSITION'] == 'GK']
dfBrazilDF = dfBrazil[dfBrazil['POSITION'] == 'DF']
dfBrazilMF = dfBrazil[dfBrazil['POSITION'] == 'MF']
dfBrazilFW = dfBrazil[dfBrazil['POSITION'] == 'FW']

#Cameroon Position Data
dfCameroonGK = dfCameroon[dfCameroon['POSITION'] == 'GK']
dfCameroonDF = dfCameroon[dfCameroon['POSITION'] == 'DF']
dfCameroonMF = dfCameroon[dfCameroon['POSITION'] == 'MF']
dfCameroonFW = dfCameroon[dfCameroon['POSITION'] == 'FW']

#Serbia Position Data
dfSerbiaGK = dfSerbia[dfSerbia['POSITION'] == 'GK']
dfSerbiaDF = dfSerbia[dfSerbia['POSITION'] == 'DF']
dfSerbiaMF = dfSerbia[dfSerbia['POSITION'] == 'MF']
dfSerbiaFW = dfSerbia[dfSerbia['POSITION'] == 'FW']

#Switzerland Position Data
dfSwitzerlandGK = dfSwitzerland[dfSwitzerland['POSITION'] == 'GK']
dfSwitzerlandDF = dfSwitzerland[dfSwitzerland['POSITION'] == 'DF']
dfSwitzerlandMF = dfSwitzerland[dfSwitzerland['POSITION'] == 'MF']
dfSwitzerlandFW = dfSwitzerland[dfSwitzerland['POSITION'] == 'FW']

plt.subplot(2,2,1)
plt.plot(dfBrazilGK['WORTH (€)'])
plt.plot(dfBrazilDF['WORTH (€)'])
plt.plot(dfBrazilMF['WORTH (€)'])
plt.plot(dfBrazilFW['WORTH (€)'])
plt.title('Brazil Position Worth')


plt.subplot(2,2,2)
plt.plot(dfCameroonGK['WORTH (€)'])
plt.plot(dfCameroonDF['WORTH (€)'])
plt.plot(dfCameroonMF['WORTH (€)'])
plt.plot(dfCameroonFW['WORTH (€)'])
plt.title('Cameroon Position Worth')

plt.subplot(2,2,3)
plt.plot(dfSerbiaGK['WORTH (€)'])
plt.plot(dfSerbiaDF['WORTH (€)'])
plt.plot(dfSerbiaMF['WORTH (€)'])
plt.plot(dfSerbiaFW['WORTH (€)'])
plt.title('Serbia Position Worth')
plt.legend(['GK','DF','MF','FW'],loc='upper left')

plt.subplot(2,2,4)
plt.plot(dfSwitzerlandGK['WORTH (€)'])
plt.plot(dfSwitzerlandDF['WORTH (€)'])
plt.plot(dfSwitzerlandMF['WORTH (€)'])
plt.plot(dfSwitzerlandFW['WORTH (€)'])
plt.title('Switzerland Position Worth')

plt.tight_layout()

plt.suptitle("Group G Position and Worth", fontsize=18,color='blue',y=1.05)
# Out:
# Text(0.5, 1.05, 'Group G Position and Worth')

# %%
#Ghana Position Data
dfGhanaGK = dfGhana[dfGhana['POSITION'] == 'GK']
dfGhanaDF = dfGhana[dfGhana['POSITION'] == 'DF']
dfGhanaMF = dfGhana[dfGhana['POSITION'] == 'MF']
dfGhanaFW = dfGhana[dfGhana['POSITION'] == 'FW']

#Portugal Position Data
dfPortugalGK = dfPortugal[dfPortugal['POSITION'] == 'GK']
dfPortugalDF = dfPortugal[dfPortugal['POSITION'] == 'DF']
dfPortugalMF = dfPortugal[dfPortugal['POSITION'] == 'MF']
dfPortugalFW = dfPortugal[dfPortugal['POSITION'] == 'FW']

#South Korea Position Data
dfSouthKoreaGK = dfSouthKorea[dfSouthKorea['POSITION'] == 'GK']
dfSouthKoreaDF = dfSouthKorea[dfSouthKorea['POSITION'] == 'DF']
dfSouthKoreaMF = dfSouthKorea[dfSouthKorea['POSITION'] == 'MF']
dfSouthKoreaFW = dfSouthKorea[dfSouthKorea['POSITION'] == 'FW']

#Uruguay Position Data
dfUruguayGK = dfUruguay[dfUruguay['POSITION'] == 'GK']
dfUruguayDF = dfUruguay[dfUruguay['POSITION'] == 'DF']
dfUruguayMF = dfUruguay[dfUruguay['POSITION'] == 'MF']
dfUruguayFW = dfUruguay[dfUruguay['POSITION'] == 'FW']

plt.subplot(2,2,1)
plt.plot(dfGhanaGK['WORTH (€)'])
plt.plot(dfGhanaDF['WORTH (€)'])
plt.plot(dfGhanaMF['WORTH (€)'])
plt.plot(dfGhanaFW['WORTH (€)'])
plt.title('Ghana Position Worth')


plt.subplot(2,2,2)
plt.plot(dfPortugalGK['WORTH (€)'])
plt.plot(dfPortugalDF['WORTH (€)'])
plt.plot(dfPortugalMF['WORTH (€)'])
plt.plot(dfPortugalFW['WORTH (€)'])
plt.title('Portugal Position Worth')

plt.subplot(2,2,3)
plt.plot(dfSouthKoreaGK['WORTH (€)'])
plt.plot(dfSouthKoreaDF['WORTH (€)'])
plt.plot(dfSouthKoreaMF['WORTH (€)'])
plt.plot(dfSouthKoreaFW['WORTH (€)'])
plt.title('South Korea Position Worth')
plt.legend(['GK','DF','MF','FW'],loc='upper right')

plt.subplot(2,2,4)
plt.plot(dfUruguayGK['WORTH (€)'])
plt.plot(dfUruguayDF['WORTH (€)'])
plt.plot(dfUruguayMF['WORTH (€)'])
plt.plot(dfUruguayFW['WORTH (€)'])
plt.title('Uruguay Position Worth')

plt.tight_layout()

plt.suptitle("Group H Position and Worth", fontsize=18,color='blue',y=1.05)
# Out:
# Text(0.5, 1.05, 'Group H Position and Worth')

# %%
df.groupby('COUNTRY')['HEIGHT'].mean().sort_values(ascending=False).head(5)
# Out:
# COUNTRY
# Serbia     187.307692
# Denmark    185.615385
# France     185.520000
# Belgium    185.153846
# Germany    185.153846
# Name: HEIGHT, dtype: float64

# %%
a = df.groupby('COUNTRY')['HEIGHT'].mean().sort_values(ascending=True).head(5)

# %%
a
# Out:
# COUNTRY
# Argentina       178.769231
# Saudi Arabia    179.000000
# Ghana           179.461538
# QATAR           179.500000
# Mexico          179.884615
# Name: HEIGHT, dtype: float64

# %%
df.groupby('AGE')['WORTH (€)'].mean().sort_values()
# Out:
# AGE
# 39     0.530000
# 40     0.800000
# 38     1.275000
# 36     2.977778
# 33     3.619643
# 32     3.690244
# 35     5.121875
# 34     5.268056
# 37     5.500000
# 31     8.968293
# 29    11.971875
# 30    12.882534
# 26    15.307143
# 28    15.940566
# 24    15.949315
# 27    16.307971
# 25    19.023214
# 20    19.254464
# 21    19.574265
# 18    21.550000
# 22    21.998529
# 23    22.448558
# 19    30.371154
# Name: WORTH (€), dtype: float64

# %%
plt.plot(df.groupby('AGE')['WORTH (€)'].mean().sort_values())
plt.xlabel('Age')
plt.ylabel('Worth')
plt.grid()

# %%
df.groupby('COUNTRY')['HEIGHT'].mean().sort_values(ascending = False).head(10)
# Out:
# COUNTRY
# Serbia         187.307692
# Denmark        185.615385
# France         185.520000
# Belgium        185.153846
# Germany        185.153846
# Senegal        184.538462
# Croatia        184.500000
# Poland         184.269231
# Switzerland    184.192308
# Iran           184.080000
# Name: HEIGHT, dtype: float64

# %%
df.groupby('COUNTRY')['HEIGHT'].mean().sort_values().head(10)
# Out:
# COUNTRY
# Argentina       178.769231
# Saudi Arabia    179.000000
# Ghana           179.461538
# QATAR           179.500000
# Mexico          179.884615
# Japan           180.038462
# Ecuador         180.269231
# Brazil          180.730769
# Australia       181.038462
# Spain           181.230769
# Name: HEIGHT, dtype: float64
